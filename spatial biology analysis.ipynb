# %% [markdown]
# <b> The purpose of the notebook: analysis of spatial biology using the Scanpy library </b>

# %%
pip install scanpy
# Out:
# Collecting scanpy
#   Downloading scanpy-1.9.1-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\super\anaconda3\lib\site-packages (from scanpy) (0.24.1)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\super\appdata\roaming\python\python38\site-packages (from scanpy) (1.22.4)
# Collecting matplotlib>=3.4
#   Downloading matplotlib-3.5.3-cp38-cp38-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4 in c:\users\super\anaconda3\lib\site-packages (from scanpy) (1.6.2)
# Requirement already satisfied: h5py>=3 in c:\users\super\appdata\roaming\python\python38\site-packages (from scanpy) (3.1.0)
# Requirement already satisfied: joblib in c:\users\super\anaconda3\lib\site-packages (from scanpy) (1.0.1)
# Collecting umap-learn>=0.3.10
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ---------------------------------------- 88.2/88.2 KB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: seaborn in c:\users\super\anaconda3\lib\site-packages (from scanpy) (0.11.1)
# Requirement already satisfied: patsy in c:\users\super\anaconda3\lib\site-packages (from scanpy) (0.5.1)
# Requirement already satisfied: networkx>=2.3 in c:\users\super\anaconda3\lib\site-packages (from scanpy) (2.5)
# Requirement already satisfied: numba>=0.41.0 in c:\users\super\anaconda3\lib\site-packages (from scanpy) (0.53.1)
# Requirement already satisfied: packaging in c:\users\super\anaconda3\lib\site-packages (from scanpy) (20.9)
# Collecting session-info
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm in c:\users\super\anaconda3\lib\site-packages (from scanpy) (4.64.0)
# Collecting anndata>=0.7.4
#   Downloading anndata-0.8.0-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.1/96.1 KB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0 in c:\users\super\anaconda3\lib\site-packages (from scanpy) (1.4.2)
# Collecting natsort
#   Downloading natsort-8.2.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in c:\users\super\anaconda3\lib\site-packages (from scanpy) (0.12.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\super\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (2.8.1)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.1-py3-none-any.whl (957 kB)
#      ------------------------------------- 957.2/957.2 KB 59.2 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\super\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\super\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\super\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\super\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (0.10.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\super\anaconda3\lib\site-packages (from networkx>=2.3->scanpy) (5.0.6)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\super\anaconda3\lib\site-packages (from numba>=0.41.0->scanpy) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\super\anaconda3\lib\site-packages (from numba>=0.41.0->scanpy) (59.5.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\super\anaconda3\lib\site-packages (from pandas>=1.0->scanpy) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\super\anaconda3\lib\site-packages (from scikit-learn>=0.22->scanpy) (2.1.0)
# Requirement already satisfied: six in c:\users\super\anaconda3\lib\site-packages (from patsy->scanpy) (1.15.0)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.7.tar.gz (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 35.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting stdlib_list
#   Downloading stdlib_list-0.8.0-py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.5/63.5 KB ? eta 0:00:00
# Requirement already satisfied: colorama in c:\users\super\appdata\roaming\python\python38\site-packages (from tqdm->scanpy) (0.4.3)
# Building wheels for collected packages: umap-learn, session-info, pynndescent
#   Building wheel for umap-learn (setup.py): started
#   Building wheel for umap-learn (setup.py): finished with status 'done'
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=8b6790dec51d8465a73f11c18310989311036b47437d468416b831735515a987
#   Stored in directory: c:\users\super\appdata\local\pip\cache\wheels\a9\3a\67\06a8950e053725912e6a8c42c4a3a241410f6487b8402542ea
#   Building wheel for session-info (setup.py): started
#   Building wheel for session-info (setup.py): finished with status 'done'
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8053 sha256=ce8a782a2ec01ef1dccb36514708c3035424bac155c6f1f15a49dc7301ccff1b
#   Stored in directory: c:\users\super\appdata\local\pip\cache\wheels\5c\1b\4d\111d73980c5c6a8e5e5905a19eccc34296cb359cac54c6c5b9
#   Building wheel for pynndescent (setup.py): started
#   Building wheel for pynndescent (setup.py): finished with status 'done'
#   Created wheel for pynndescent: filename=pynndescent-0.5.7-py3-none-any.whl size=54286 sha256=981effce9d75b9e076532c75b799bb706adf349f5da96d469d6847e3ea4007f4
#   Stored in directory: c:\users\super\appdata\local\pip\cache\wheels\1b\38\fe\99e22fbae88abd1c5e8d99253cba6d1c590cc7a94408bff3bf
# Successfully built umap-learn session-info pynndescent
# Installing collected packages: stdlib_list, session-info, natsort, fonttools, matplotlib, pynndescent, anndata, umap-learn, scanpy
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.3.4
#     Uninstalling matplotlib-3.3.4:
#       Successfully uninstalled matplotlib-3.3.4
# Successfully installed anndata-0.8.0 fonttools-4.37.1 matplotlib-3.5.3 natsort-8.2.0 pynndescent-0.5.7 scanpy-1.9.1 session-info-1.0.0 stdlib_list-0.8.0 umap-learn-0.5.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fbprophet 0.7.1 requires cmdstanpy==0.9.5, which is not installed.
# fbprophet 0.7.1 requires setuptools-git>=1.2, which is not installed.
# flair 0.10 requires more-itertools~=8.8.0, but you have more-itertools 8.12.0 which is incompatible.
# flair 0.10 requires transformers>=4.0.0, but you have transformers 3.0.2 which is incompatible.

# %%
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sc.logging.print_versions()
sc.set_figure_params(facecolor="white", figsize=(8, 8))
sc.settings.verbosity = 3
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.1
# -----
# PIL                 8.2.0
# anyio               NA
# attr                21.4.0
# babel               2.9.0
# backcall            0.2.0
# bottleneck          1.3.2
# brotli              NA
# certifi             2022.05.18.1
# cffi                1.14.5
# chardet             4.0.0
# charset_normalizer  2.0.12
# cloudpickle         1.6.0
# colorama            0.4.3
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.04.0
# dateutil            2.8.1
# decorator           5.0.6
# fsspec              2021.11.1
# google              NA
# h5py                3.1.0
# idna                3.3
# ipykernel           5.3.4
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.17.2
# jinja2              3.0.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.4.1
# jupyterlab_server   2.4.0
# kiwisolver          1.3.1
# llvmlite            0.36.0
# markupsafe          2.0.1
# matplotlib          3.5.3
# mpl_toolkits        NA
# natsort             8.2.0
# nbclassic           NA
# nbformat            5.1.3
# nt                  NA
# ntsecuritycon       NA
# numba               0.53.1
# numexpr             2.7.3
# numpy               1.22.4
# packaging           20.9
# pandas              1.4.2
# parso               0.7.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.17
# psutil              5.8.0
# pvectorc            NA
# pyarrow             7.0.0
# pygments            2.8.1
# pyparsing           2.4.7
# pyrsistent          NA
# pythoncom           NA
# pytz                2021.1
# pywintypes          NA
# requests            2.27.1
# scipy               1.6.2
# seaborn             0.11.1
# send2trash          NA
# session_info        1.0.0
# six                 1.15.0
# sklearn             0.24.1
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# statsmodels         0.12.2
# storemagic          NA
# tblib               1.7.0
# tlz                 0.11.0
# toolz               0.11.1
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# urllib3             1.26.8
# wcwidth             0.2.5
# win32api            NA
# win32com            NA
# win32security       NA
# xxhash              NA
# yaml                5.4.1
# zmq                 20.0.0
# zope                NA
# -----
# IPython             7.22.0
# jupyter_client      6.1.12
# jupyter_core        4.7.1
# jupyterlab          3.0.14
# notebook            6.3.0
# -----
# Python 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]
# Windows-10-10.0.19041-SP0
# -----
# Session information updated at 2022-09-07 15:59

# %%
adata = sc.datasets.visium_sge(sample_id="V1_Human_Lymph_Node")
adata.var_names_make_unique()
adata.var["mt"] = adata.var_names.str.startswith("MT-")
sc.pp.calculate_qc_metrics(adata, qc_vars=["mt"], inplace=True)
# Out:
# reading data\V1_Human_Lymph_Node\filtered_feature_bc_matrix.h5
#  (0:00:01)
# C:\Users\super\anaconda3\lib\site-packages\anndata\_core\anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4035 × 36601
#     obs: 'in_tissue', 'array_row', 'array_col', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
fig, axs = plt.subplots(1, 4, figsize=(15, 4))
sns.distplot(adata.obs["total_counts"], kde=False, ax=axs[0])
sns.distplot(adata.obs["total_counts"][adata.obs["total_counts"] < 10000], kde=False, bins=40, ax=axs[1])
sns.distplot(adata.obs["n_genes_by_counts"], kde=False, bins=60, ax=axs[2])
sns.distplot(adata.obs["n_genes_by_counts"][adata.obs["n_genes_by_counts"] < 4000], kde=False, bins=60, ax=axs[3])
# Out:
# C:\Users\super\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='n_genes_by_counts'>

# %%
sc.pp.filter_cells(adata, min_counts=5000)
sc.pp.filter_cells(adata, max_counts=35000)
adata = adata[adata.obs["pct_counts_mt"] < 20]
print(f"#cells after MT filter: {adata.n_obs}")
sc.pp.filter_genes(adata, min_cells=10)
# Out:
# filtered out 44 cells that have less than 5000 counts
# filtered out 130 cells that have more than 35000 counts
# #cells after MT filter: 3861
# filtered out 16916 genes that are detected in less than 10 cells
# C:\Users\super\anaconda3\lib\site-packages\scanpy\preprocessing\_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number

# %%
sc.pp.normalize_total(adata, inplace=True)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, flavor="seurat", n_top_genes=2000)
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
#     finished (0:00:00)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
pip install leidenalg
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.tl.leiden(adata, key_added="clusters")
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:01)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:08)
# running Leiden clustering
#     finished: found 10 clusters and added
#     'clusters', the cluster labels (adata.obs, categorical) (0:00:00)

# %% [markdown]
# Visualization in spatial coordination

# %%
plt.rcParams["figure.figsize"] = (8, 8)
sc.pl.spatial(adata, img_key="hires", color=["total_counts", "n_genes_by_counts"])

# %%
sc.pl.spatial(adata, img_key="hires", color="clusters", size=1.5)

# %%
sc.tl.rank_genes_groups(adata, "clusters", method="t-test")
sc.pl.rank_genes_groups_heatmap(adata, groups="5", n_genes=10, groupby="clusters")
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:03)
# WARNING: dendrogram data not found (using key=dendrogram_clusters). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_clusters']`
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: 0, 1, 2, etc.
# var_group_labels: 5
